# %% [markdown]
# # Compass.UOL - Sprint 4 & 5
# ## Equipe 3 - José Pedro, Pedro Montenegro, Natália Cardoso, Renan Mazzilli

# %% [markdown]
# ## Treinamento do modelo XGBoost no Sagemaker

# %% [markdown]
# ### Imports e instalações necessárias

# %%
# Instalar as bibliotecas necessárias para o projeto localmente
# %pip install pandas boto3 joblib scikit-learn sagemaker seaborn

# Importar as bibliotecas necessárias para o projeto no ambiente local
import time
import boto3
import sagemaker
import pandas as pd
from sagemaker import image_uris
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Configuração base do treinamento e declaração de variáveis globais

# %%
# Carregando configurações do arquivo JSON de configuração
with open('config.json', 'r') as config_file:
    config = json.load(config_file)

# Atribuir as variáveis de configuração a variáveis locais
table_name = config['table_name']
model_metrics_table = config['model_metrics_table']
dataset_path = config['dataset_path']
processed_dataset_path = config['processed_dataset_path']
model_path = config['model_path']
profile_name = config['profile_name']
aws_region = config['aws_region']

# Obtendo a role do SageMaker e o nome do bucket S3
role = config['role_name'] 
bucket_name = config['bucket_name']

# Inicialização da sessão AWS e dos clientes do DynamoDB, IAM e S3
session = boto3.Session(profile_name=profile_name, region_name=aws_region)
dynamodb_client = session.client('dynamodb')
iam_client = session.client('iam')
s3_client = boto3.client('s3')

# Inicializando a sessão do SageMaker e o cliente do SageMaker
sagemaker_session = sagemaker.Session()
sagemaker_client = sagemaker_session.boto_session.client('sagemaker')

# Definindo o local de saída dos dados de treinamento
output_location = f's3://{bucket_name}/output'

# %% [markdown]
# ### Carregando dados do DynamoDB e realizando o *split* entre dados de treino e dados de teste para o treinamento do modelo

# %%
# Função para carregar os dados do DynamoDB para o DataFrame
def fetch_data_from_dynamodb(table_name):
    session = boto3.Session()
    dynamodb = session.resource('dynamodb')
    table = dynamodb.Table(table_name)
    response = table.scan()
    return pd.DataFrame(response['Items'])
# Preparar os dados para treinamento e validação do modelo no SageMaker seguindo a documentação do XGBoost
def prepare_data(df):
    df['label_avg_price_per_room'] = df['label_avg_price_per_room'].astype(int)
    X = df.drop(columns=['label_avg_price_per_room'])
    y = df['label_avg_price_per_room']
    return train_test_split(X, y, test_size=0.25, random_state=42)

# Carregar dados do DynamoDB
df = fetch_data_from_dynamodb('HotelReservations-test4')

# Preparar dados para treinamento e validação
X_train, X_test, y_train, y_test = prepare_data(df)

# Verifique a distribuição dos rótulos
print(y_train.value_counts())
print(y_test.value_counts())

# Mapear rótulos para o intervalo [0, num_class)
label_mapping = {value: idx for idx, value in enumerate(sorted(y_train.unique()))}
y_train = y_train.map(label_mapping)
y_test = y_test.map(label_mapping)

# Converter valores booleanos para inteiros
X_train = X_train.map(lambda x: int(x) if isinstance(x, bool) else x)
X_test = X_test.map(lambda x: int(x) if isinstance(x, bool) else x)

# Salvar os dados localmente sem cabeçalho
train_data = pd.concat([y_train, X_train], axis=1)
test_data = pd.concat([y_test, X_test], axis=1)

train_data.to_csv('train.csv', index=False, header=False)
test_data.to_csv('test.csv', index=False, header=False)

# Fazer upload dos dados para o S3
s3_client.upload_file('train.csv', bucket_name, 'train/train.csv')
s3_client.upload_file('test.csv', bucket_name, 'test/test.csv')

s3_train_data = f's3://{bucket_name}/train/train.csv'
s3_test_data = f's3://{bucket_name}/test/test.csv'
# Out:
# label_avg_price_per_room
# 2    371
# 1    246
# 3    220
# Name: count, dtype: int64
# label_avg_price_per_room
# 2    132
# 1     79
# 3     68
# Name: count, dtype: int64

# %% [markdown]
# ### Treinamento com Container Image do Modelo XGBoost

# %%
# Recuperar a URI da imagem do XGBoost
container = image_uris.retrieve(framework='xgboost', region=boto3.Session().region_name, version='latest')

# Configuração do estimador XGBoost
xgboost = sagemaker.estimator.Estimator(
    image_uri=container,
    role=role,
    instance_count=1,
    instance_type='ml.m5.2xlarge',
    output_path=output_location,
    sagemaker_session=sagemaker_session
)

# Definindo os hiperparâmetros
xgboost.set_hyperparameters(
    num_round=100,
    objective='multi:softprob',
    num_class=3
)

# Configurar os inputs de treinamento e validação usando as URIs S3
train_input = sagemaker.inputs.TrainingInput(s3_data=s3_train_data, content_type='csv')
validation_input = sagemaker.inputs.TrainingInput(s3_data=s3_test_data, content_type='csv')

# Treinamento do modelo
data_channels = {'train': train_input, 'validation': validation_input}
xgboost.fit(data_channels)

# Esperar pelo treinamento e coletar logs
while True:
    training_job_name = xgboost.latest_training_job.name
    status = sagemaker_client.describe_training_job(TrainingJobName=training_job_name)['TrainingJobStatus']
    if status == 'Completed':
        print("Training completed successfully.")
        break
    elif status == 'Failed':
        print("Training failed. Check the logs for details.")
        break
    else:
        print(f"Training job status: {status}. Waiting for completion...")
        time.sleep(60)
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: xgboost-2024-05-24-18-50-31-520
# 2024-05-24 18:50:31 Starting - Starting the training job...
# 2024-05-24 18:50:47 Starting - Preparing the instances for training...
# 2024-05-24 18:51:12 Downloading - Downloading input data...
# 2024-05-24 18:51:32 Downloading - Downloading the training image...
# 2024-05-24 18:52:28 Training - Training image download completed. Training in progress.
# 2024-05-24 18:52:28 Uploading - Uploading generated training modelArguments: train
# [2024-05-24:18:52:21:INFO] Running standalone xgboost training.
# [2024-05-24:18:52:21:INFO] File size need to be processed in the node: 0.24mb. Available memory size in the node: 23881.56mb
# [2024-05-24:18:52:21:INFO] Determined delimiter of CSV input is ','
# [18:52:21] S3DistributionType set as FullyReplicated
# [18:52:21] 837x34 matrix with 28458 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2024-05-24:18:52:21:INFO] Determined delimiter of CSV input is ','
# [18:52:21] S3DistributionType set as FullyReplicated
# [18:52:21] 279x34 matrix with 9486 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [0]#011train-merror:0.212664#011validation-merror:0.387097
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-merror:0.192354#011validation-merror:0.379928
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-merror:0.178017#011validation-merror:0.401434
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-merror:0.149343#011validation-merror:0.387097
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-merror:0.142174#011validation-merror:0.394265
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-merror:0.129032#011validation-merror:0.394265
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-merror:0.11828#011validation-merror:0.387097
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-merror:0.101553#011validation-merror:0.397849
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-merror:0.09319#011validation-merror:0.390681
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-merror:0.082437#011validation-merror:0.387097
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-merror:0.074074#011validation-merror:0.397849
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-merror:0.058542#011validation-merror:0.387097
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-merror:0.056153#011validation-merror:0.383513
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-merror:0.052569#011validation-merror:0.369176
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-merror:0.039427#011validation-merror:0.376344
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-merror:0.033453#011validation-merror:0.37276
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-merror:0.033453#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-merror:0.035842#011validation-merror:0.376344
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-merror:0.029869#011validation-merror:0.362007
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-merror:0.029869#011validation-merror:0.379928
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-merror:0.02509#011validation-merror:0.379928
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-merror:0.021505#011validation-merror:0.37276
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-merror:0.016726#011validation-merror:0.387097
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-merror:0.014337#011validation-merror:0.379928
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [24]#011train-merror:0.013142#011validation-merror:0.376344
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [25]#011train-merror:0.008363#011validation-merror:0.369176
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [26]#011train-merror:0.005974#011validation-merror:0.358423
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [27]#011train-merror:0.005974#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [28]#011train-merror:0.005974#011validation-merror:0.37276
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [29]#011train-merror:0.004779#011validation-merror:0.376344
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [30]#011train-merror:0.004779#011validation-merror:0.383513
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [31]#011train-merror:0.004779#011validation-merror:0.383513
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [32]#011train-merror:0.003584#011validation-merror:0.383513
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [33]#011train-merror:0.002389#011validation-merror:0.376344
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [34]#011train-merror:0.001195#011validation-merror:0.37276
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [35]#011train-merror:0.001195#011validation-merror:0.37276
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [36]#011train-merror:0.001195#011validation-merror:0.37276
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [37]#011train-merror:0.001195#011validation-merror:0.376344
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [38]#011train-merror:0.001195#011validation-merror:0.37276
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [39]#011train-merror:0#011validation-merror:0.37276
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [40]#011train-merror:0#011validation-merror:0.37276
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [41]#011train-merror:0#011validation-merror:0.37276
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [42]#011train-merror:0#011validation-merror:0.369176
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [43]#011train-merror:0#011validation-merror:0.37276
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [44]#011train-merror:0#011validation-merror:0.37276
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [45]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [46]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [47]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [48]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [49]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [50]#011train-merror:0#011validation-merror:0.376344
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [51]#011train-merror:0#011validation-merror:0.376344
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [52]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [53]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [54]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [55]#011train-merror:0#011validation-merror:0.369176
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [56]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [57]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [58]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [59]#011train-merror:0#011validation-merror:0.369176
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [60]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [61]#011train-merror:0#011validation-merror:0.365591
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [62]#011train-merror:0#011validation-merror:0.369176
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [63]#011train-merror:0#011validation-merror:0.362007
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [64]#011train-merror:0#011validation-merror:0.362007
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [65]#011train-merror:0#011validation-merror:0.354839
# [66]#011train-merror:0#011validation-merror:0.358423
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [67]#011train-merror:0#011validation-merror:0.358423
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [68]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [69]#011train-merror:0#011validation-merror:0.358423
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [70]#011train-merror:0#011validation-merror:0.358423
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [71]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [72]#011train-merror:0#011validation-merror:0.351254
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [73]#011train-merror:0#011validation-merror:0.351254
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [74]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [75]#011train-merror:0#011validation-merror:0.351254
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [76]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [77]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [78]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [79]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [80]#011train-merror:0#011validation-merror:0.351254
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [81]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [82]#011train-merror:0#011validation-merror:0.351254
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [83]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [84]#011train-merror:0#011validation-merror:0.34767
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [85]#011train-merror:0#011validation-merror:0.34767
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [86]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [87]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [88]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [89]#011train-merror:0#011validation-merror:0.358423
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [90]#011train-merror:0#011validation-merror:0.354839
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [91]#011train-merror:0#011validation-merror:0.358423
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [92]#011train-merror:0#011validation-merror:0.351254
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [93]#011train-merror:0#011validation-merror:0.358423
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [94]#011train-merror:0#011validation-merror:0.351254
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [95]#011train-merror:0#011validation-merror:0.351254
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [96]#011train-merror:0#011validation-merror:0.351254
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [97]#011train-merror:0#011validation-merror:0.351254
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [98]#011train-merror:0#011validation-merror:0.351254
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [18:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [99]#011train-merror:0#011validation-merror:0.354839
#
# 2024-05-24 18:52:41 Completed - Training job completed
# Training seconds: 89
# Billable seconds: 89
# Training completed successfully.

# %% [markdown]
# ## Deploy teste do modelo XGBoost para obtenção de métricas

# %%
# Deploy do modelo como um endpoint
predictor = xgboost.deploy(
    initial_instance_count=1,
    instance_type='ml.m5.large'
)

# Fazer previsões
import numpy as np
import json
from decimal import Decimal
from io import StringIO
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sagemaker.serializers import CSVSerializer

# Converter valores Decimal para float usando applymap
X_test_float = X_test.applymap(lambda x: float(x) if isinstance(x, Decimal) else x)

# Configurar o serializador para CSV
predictor.serializer = CSVSerializer()

# Converter os dados de teste para formato NumPy
test_data_no_label = X_test_float.to_numpy()

# Fazer previsões
response = predictor.predict(test_data_no_label)

# Verificar o formato da resposta
print("Raw response:")
print(response)

# Tentar decodificar a resposta corretamente
try:
    predictions_array = np.array(json.loads(response))
except json.JSONDecodeError as e:
    print(f"JSONDecodeError: {e}")
    # Tentar outra abordagem de processamento da resposta
    try:
        predictions_array = np.array(eval(response))
    except Exception as e:
        print(f"Error decoding response: {e}")
        predictions_array = None

# Verifique se predictions_array foi criado corretamente
if predictions_array is not None:
    predicted_labels = np.argmax(predictions_array, axis=1)

    # Inverter o mapeamento dos rótulos (opcional, se necessário)
    inverse_label_mapping = {v: k for k, v in label_mapping.items()}
    predicted_labels = np.vectorize(inverse_label_mapping.get)(predicted_labels)
    y_test_mapped = y_test.map(inverse_label_mapping)

    # Calcular as métricas
    accuracy = accuracy_score(y_test_mapped, predicted_labels)
    precision = precision_score(y_test_mapped, predicted_labels, average='weighted')
    recall = recall_score(y_test_mapped, predicted_labels, average='weighted')
    f1 = f1_score(y_test_mapped, predicted_labels, average='weighted')
    conf_matrix = confusion_matrix(y_test_mapped, predicted_labels)

    # Imprimir as métricas
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print(f'F1 Score: {f1}')
    print('Confusion Matrix:')
    print(conf_matrix)
else:
    print("Failed to decode predictions array.")

# Encerrar o endpoint para evitar cobranças adicionais
predictor.delete_endpoint()
# Out:
# INFO:sagemaker:Creating model with name: xgboost-2024-05-23-04-11-33-142
# INFO:sagemaker:Creating endpoint-config with name xgboost-2024-05-23-04-11-33-142
# INFO:sagemaker:Creating endpoint with name xgboost-2024-05-23-04-11-33-142
# -----!Raw response:
# b'[0.9900056719779968, 0.009982947260141373, 1.1388174243620597e-05],[0.8370394706726074, 0.16161483526229858, 0.0013457279419526458],[0.7032768130302429, 0.2613142728805542, 0.035408854484558105],[0.6987595558166504, 0.2988429367542267, 0.0023975346703082323],[0.9917477369308472, 0.008210496045649052, 4.173181878286414e-05],[0.8185534477233887, 0.1702447235584259, 0.011201783083379269],[0.3845750391483307, 0.6021490097045898, 0.013275918550789356],[0.0030306403059512377, 0.5789738297462463, 0.4179955720901489],[0.00449243513867259, 0.9930773973464966, 0.002430172171443701],[0.5013061165809631, 0.49178487062454224, 0.0069090500473976135],[0.11467360705137253, 0.7762438654899597, 0.10908257961273193],[0.9358463883399963, 0.032888755202293396, 0.031264856457710266],[0.3822445273399353, 0.6028234958648682, 0.014931981451809406],[0.11627139896154404, 0.7387983798980713, 0.14493021368980408],[0.45775306224823, 0.13528740406036377, 0.40695950388908386],[0.4587438106536865, 0.5014813542366028, 0.03977486118674278],[0.024018170312047005, 0.9745649695396423, 0.0014168636407703161],[0.7204363346099854, 0.277267724275589, 0.0022959799971431494],[0.2023780196905136, 0.78534334897995, 0.012278640642762184],[0.015645591542124748, 0.9187890291213989, 0.06556536257266998],[0.951235830783844, 0.03609192743897438, 0.012672255747020245],[0.13776321709156036, 0.4063095152378082, 0.4559272825717926],[0.974922239780426, 0.02250903844833374, 0.002568715950474143],[0.022305412217974663, 0.7822583317756653, 0.1954362690448761],[0.05596548318862915, 0.8710698485374451, 0.07296466827392578],[0.9639611840248108, 0.03517575562000275, 0.0008631029049865901],[9.384697477798909e-05, 0.011263657361268997, 0.9886425137519836],[0.06252765655517578, 0.6048488616943359, 0.33262351155281067],[0.00031228718580678105, 0.005208284594118595, 0.9944794178009033],[0.000125661856145598, 0.0013233628123998642, 0.9985509514808655],[0.03509962186217308, 0.4142168462276459, 0.5506835579872131],[0.0005359381902962923, 0.06524790823459625, 0.9342161417007446],[0.005351869855076075, 0.8585470914840698, 0.13610103726387024],[0.0007092181476764381, 0.03443576395511627, 0.9648550748825073],[0.997122585773468, 0.002775725210085511, 0.00010168393782805651],[0.12295560538768768, 0.44124752283096313, 0.43579691648483276],[0.03633762151002884, 0.5695136785507202, 0.39414870738983154],[0.01919955015182495, 0.966012716293335, 0.014787712134420872],[0.07025134563446045, 0.421789288520813, 0.5079593658447266],[0.9812271595001221, 0.01764487288892269, 0.0011279284954071045],[0.7651304006576538, 0.23224395513534546, 0.0026256872806698084],[0.029313478618860245, 0.30192241072654724, 0.6687641143798828],[0.2574993073940277, 0.7169803977012634, 0.02552035078406334],[0.03807545453310013, 0.503853976726532, 0.4580705463886261],[0.2886330187320709, 0.6965072154998779, 0.014859811402857304],[5.4496555094374344e-05, 0.002479765797033906, 0.9974657297134399],[0.12142552435398102, 0.7013719081878662, 0.17720259726047516],[0.7837808132171631, 0.19345512986183167, 0.022764060646295547],[0.716240644454956, 0.010656256228685379, 0.27310311794281006],[0.9960699081420898, 0.001976331463083625, 0.0019537692423909903],[0.00036803653347305954, 0.0007212322670966387, 0.9989107847213745],[0.007109189406037331, 0.7436666488647461, 0.24922418594360352],[0.0789915919303894, 0.5824503302574158, 0.3385581076145172],[0.002000306034460664, 0.14347298443317413, 0.8545267581939697],[0.2670658826828003, 0.4761025011539459, 0.2568316161632538],[0.5476562976837158, 0.45054689049720764, 0.0017967630410566926],[0.9992019534111023, 0.00030979327857494354, 0.00048824414261616766],[0.0019255931256338954, 0.9538793563842773, 0.044195059686899185],[0.006920239422470331, 0.9571421146392822, 0.03593766689300537],[0.005598812364041805, 0.07429734617471695, 0.9201038479804993],[0.9995986819267273, 0.0003498105506878346, 5.156004408490844e-05],[0.9785163402557373, 0.021111244335770607, 0.00037250161403790116],[0.11324677616357803, 0.82 ...
# JSONDecodeError: Extra data: line 1 column 67 (char 66)
# /tmp/ipykernel_97/1499511269.py:16: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   X_test_float = X_test.applymap(lambda x: float(x) if isinstance(x, Decimal) else x)
# INFO:sagemaker:Deleting endpoint configuration with name: xgboost-2024-05-23-04-11-33-142
# Accuracy: 0.7133757961783439
# Precision: 0.7188837234525053
# Recall: 0.7133757961783439
# F1 Score: 0.7147494945196413
# Confusion Matrix:
# [[78 24  4]
#  [23 87 13]
#  [ 1 25 59]]
# INFO:sagemaker:Deleting endpoint with name: xgboost-2024-05-23-04-11-33-142
